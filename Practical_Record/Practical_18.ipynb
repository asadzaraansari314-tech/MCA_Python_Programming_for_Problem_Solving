# %%
# Import necessary libraries
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA

# Load the digits dataset
digits = load_digits()
X = digits.data       # Features (64 features per sample)

# Apply PCA to reduce dimensions to 2
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Print the explained variance ratio
print("Explained Variance Ratio for each component:", pca.explained_variance_ratio_)
print("Total Variance Explained:", sum(pca.explained_variance_ratio_))
# Out:
# Explained Variance Ratio for each component: [0.14890594 0.13618771]
# Total Variance Explained: 0.28509364823699296
